# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.gofplots import qqplot
pd.set_option("display.max_columns", None)
import jinja2

# %%
df_cars = pd.read_csv("C:/Users/pc/Desktop/ProyectoIntegrador/ML_cars.csv")
df_cars.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# 0       48.8        2548       dohc           four         130       mpfi
# 1       48.8        2548       dohc           four         130       mpfi
# 2       52.4        2823       ohcv            six         152       mpfi
# 3       54.3        2337        ohc           four         109       mpfi
# 4       54.3        2824        ohc           five         136       mpfi
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0

# %%
df_cars.drop(df_cars.columns[0], axis=1, inplace=True)
df_cars.head()
# Out:
#    symboling                   CarName fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# 0       48.8        2548       dohc           four         130       mpfi
# 1       48.8        2548       dohc           four         130       mpfi
# 2       52.4        2823       ohcv            six         152       mpfi
# 3       54.3        2337        ohc           four         109       mpfi
# 4       54.3        2824        ohc           five         136       mpfi
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    int64
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    int64
#  15  enginesize        205 non-null    int64
#  16  fuelsystem        205 non-null    object
#  17  boreratio         205 non-null    float64
#  18  stroke            205 non-null    float64
#  19  compressionratio  205 non-null    float64
#  20  horsepower        205 non-null    int64
#  21  peakrpm           205 non-null    int64
#  22  citympg           205 non-null    int64
#  23  highwaympg        205 non-null    int64
#  24  price             205 non-null    float64
#  25  gama              205 non-null    object
# dtypes: float64(8), int64(9), object(9)
# memory usage: 41.8+ KB

# %%
mediana = df_cars['price'].median()
print("Mediana de 'price':", mediana)
# Out:
# Mediana de 'price': 10295.0

# %%
df_cars['gama'] = df_cars['price'].apply(lambda x: 'alta' if x >= mediana else 'baja')
df_cars.head()
# Out:
#    symboling                   CarName fueltype aspiration  doornumber  \
# 0          3        alfa-romero giulia      gas        std           2
# 1          3       alfa-romero stelvio      gas        std           2
# 2          1  alfa-romero Quadrifoglio      gas        std           2
# 3          2               audi 100 ls      gas        std           4
# 4          2                audi 100ls      gas        std           4
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype  cylindernumber  enginesize fuelsystem  \
# 0       48.8        2548       dohc               4         130       mpfi
# 1       48.8        2548       dohc               4         130       mpfi
# 2       52.4        2823       ohcv               6         152       mpfi
# 3       54.3        2337        ohc               4         109       mpfi
# 4       54.3        2824        ohc               5         136       mpfi
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg    price  gama
# 0          27  13495.0  alta
# 1          27  16500.0  alta
# 2          26  16500.0  alta
# 3          30  13950.0  alta
# 4          22  17450.0  alta

# %%
df_cars["cylindernumber"] =df_cars["cylindernumber"].map({"four":4,
                                                 "six":6,
                                                 "five":5,
                                                 "eight":8,
                                                 "two":2,
                                                 "twelve":12,
                                                 "three":3})

# %%
df_cars["doornumber"]=df_cars["doornumber"].map({"four":4,"two":2})

# %%
variables_numericas = df_cars.select_dtypes(include=np.number)
variables_categoricas = df_cars.select_dtypes(include=['object', 'category'])

variables_numericas
# Out:
#      symboling  doornumber  wheelbase  carlength  carwidth  carheight  \
# 0            3           2       88.6      168.8      64.1       48.8
# 1            3           2       88.6      168.8      64.1       48.8
# 2            1           2       94.5      171.2      65.5       52.4
# 3            2           4       99.8      176.6      66.2       54.3
# 4            2           4       99.4      176.6      66.4       54.3
# ..         ...         ...        ...        ...       ...        ...
# 200         -1           4      109.1      188.8      68.9       55.5
# 201         -1           4      109.1      188.8      68.8       55.5
# 202         -1           4      109.1      188.8      68.9       55.5
# 203         -1           4      109.1      188.8      68.9       55.5
# 204         -1           4      109.1      188.8      68.9       55.5
#
#      curbweight  cylindernumber  enginesize  boreratio  stroke  \
# 0          2548               4         130       3.47    2.68
# 1          2548               4         130       3.47    2.68
# 2          2823               6         152       2.68    3.47
# 3          2337               4         109       3.19    3.40
# 4          2824               5         136       3.19    3.40
# ..          ...             ...         ...        ...     ...
# 200        2952               4         141       3.78    3.15
# 201        3049               4         141       3.78    3.15
# 202        3012               6         173       3.58    2.87
# 203        3217               6         145       3.01    3.40
# 204        3062               4         141       3.78    3.15
#
#      compressionratio  horsepower  peakrpm  citympg  highwaympg    price
# 0                 9.0         111     5000       21          27  13495.0
# 1                 9.0         111     5000       21          27  16500.0
# 2                 9.0         154     5000       19          26  16500.0
# 3                10.0         102     5500       24          30  13950.0
# 4                 8.0         115     5500       18          22  17450.0
# ..                ...         ...      ...      ...         ...      ...
# 200               9.5         114     5400       23          28  16845.0
# 201               8.7         160     5300       19          25  19045.0
# 202               8.8         134     5500       18          23  21485.0
# 203              23.0         106     4800       26          27  22470.0
# 204               9.5         114     5400       19          25  22625.0
#
# [205 rows x 17 columns]

# %%
df_num=variables_numericas

# %%
correlation_matrix= df_num.corr()
correlation_matrix
# Out:
#                   symboling  doornumber  wheelbase  carlength  carwidth  \
# symboling          1.000000   -0.664073  -0.531954  -0.357612 -0.232919
# doornumber        -0.664073    1.000000   0.447357   0.398568  0.207168
# wheelbase         -0.531954    0.447357   1.000000   0.874587  0.795144
# carlength         -0.357612    0.398568   0.874587   1.000000  0.841118
# carwidth          -0.232919    0.207168   0.795144   0.841118  1.000000
# carheight         -0.541038    0.552208   0.589435   0.491029  0.279210
# curbweight        -0.227691    0.197379   0.776386   0.877728  0.867032
# cylindernumber    -0.113129   -0.016009   0.339507   0.430672  0.545007
# enginesize        -0.105790    0.020742   0.569329   0.683360  0.735433
# boreratio         -0.130051    0.119258   0.488750   0.606454  0.559150
# stroke            -0.008735   -0.011082   0.160959   0.129533  0.182942
# compressionratio  -0.178515    0.177888   0.249786   0.158414  0.181129
# horsepower         0.070873   -0.126947   0.353294   0.552623  0.640732
# peakrpm            0.273606   -0.247668  -0.360469  -0.287242 -0.220012
# citympg           -0.035823   -0.012417  -0.470414  -0.670909 -0.642704
# highwaympg         0.034606   -0.036330  -0.544082  -0.704662 -0.677218
# price             -0.079978    0.031835   0.577816   0.682920  0.759325
#
#                   carheight  curbweight  cylindernumber  enginesize  \
# symboling         -0.541038   -0.227691       -0.113129   -0.105790
# doornumber         0.552208    0.197379       -0.016009    0.020742
# wheelbase          0.589435    0.776386        0.339507    0.569329
# carlength          0.491029    0.877728        0.430672    0.683360
# carwidth           0.279210    0.867032        0.545007    0.735433
# carheight          1.000000    0.295572       -0.013995    0.067149
# curbweight         0.295572    1.000000        0.609727    0.850594
# cylindernumber    -0.013995    0.609727        1.000000    0.846031
# enginesize         0.067149    0.850594        0.846031    1.000000
# boreratio          0.171071    0.648480        0.231399    0.583774
# stroke            -0.055307    0.168790        0.008210    0.203129
# compressionratio   0.261214    0.151362       -0.020002    0.028971
# horsepower        -0.108802    0.750739        0.692016    0.809769
# peakrpm           -0.320411   -0.266243       -0.124172   -0.244660
# citympg           -0.048640   -0.757414       -0.445837   -0.653658
# highwaympg        -0.107358   -0.797465       -0.466666   -0.677470
# price              0.119336    0.835305        0.718305    0.874145
#
#                   boreratio    stroke  compressionratio  horsepower   peakrpm  \
# symboling         -0.130051 -0.008735         -0.178515    0.070873  0.273606
# doornumber         0.119258 -0.011082          0.177888   -0.126947 -0.247668
# wheelbase          0.488750  0.160959          0.249786    0.353294 -0.360469
# carlength          0.606454  0.129533          0.158414    0.552623 -0.287242
# carwidth           0.559150  0.182942          0.181129    0.640732 -0.220012
# carheight          0.171071 -0.055307          0.261214   -0.108802 -0.320411
# curbweight         0.648480  0.168790          0.151362    0.750739 -0.266243
# cylindernumber     0.231399  0.008210         -0.020002    0.692016 -0.124172
# enginesize         0.583774  0.203129          0.028971    0.809769 -0.244660
# boreratio          1.000000 -0.055909          0.005197    0.573677 -0.254976
# stroke            -0.055909  1.000000          0.186110    0.080940 -0.067964
# compressionratio   0.005197  0.186110          1.000000   -0.204326 -0.435741
# horsepower         0.573677  0.080940         -0.204326    1.000000  0.131073
# peakrpm           -0.254976 -0.067964         -0.435741    0.131073  1.000000
# citympg           -0.584532 -0.042145          0.324701   -0.801456 -0.113544
# highwaympg        -0.587012 -0.043931          0.265201   -0.770544 -0.054275
# price              0.553173  0.079443          0.067984    0.808139 -0.085267
#
#                    citympg  highwaympg     price
# symboling        -0.035823    0.034606 -0.079978
# doornumber       -0.012417   -0.036330  0.031835
# wheelbase        -0.470414   -0.544082  0.577816
# carlength        -0.670909   -0.704662  0.682920
# carwidth         -0.642704   -0.677218  0.759325
# carheight        -0.048640   -0.107358  0.119336
# curbweight       -0.757414   -0.797465  0.835305
# cylindernumber   -0.445837   -0.466666  0.718305
# enginesize       -0.653658   -0.677470  0.874145
# boreratio        -0.584532   -0.587012  0.553173
# stroke           -0.042145   -0.043931  0.079443
# compressionratio  0.324701    0.265201  0.067984
# horsepower       -0.801456   -0.770544  0.808139
# peakrpm          -0.113544   -0.054275 -0.085267
# citympg           1.000000    0.971337 -0.685751
# highwaympg        0.971337    1.000000 -0.697599
# price            -0.685751   -0.697599  1.000000

# %%
correlation_matrix = correlation_matrix.round(2)
correlation_table = correlation_matrix.style.background_gradient(cmap='coolwarm')
correlation_table
# Out:
# <style type="text/css">
# #T_d4afa_row0_col0, #T_d4afa_row1_col1, #T_d4afa_row2_col2, #T_d4afa_row3_col3, #T_d4afa_row4_col4, #T_d4afa_row5_col5, #T_d4afa_row6_col6, #T_d4afa_row7_col7, #T_d4afa_row8_col8, #T_d4afa_row9_col9, #T_d4afa_row10_col10, #T_d4afa_row11_col11, #T_d4afa_row12_col12, #T_d4afa_row13_col13, #T_d4afa_row14_col14, #T_d4afa_row15_col15, #T_d4afa_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d4afa_row0_col1, #T_d4afa_row0_col5, #T_d4afa_row1_col0, #T_d4afa_row6_col15, #T_d4afa_row11_col13, #T_d4afa_row12_col14, #T_d4afa_row13_col10, #T_d4afa_row13_col11, #T_d4afa_row14_col12, #T_d4afa_row15_col2, #T_d4afa_row15_col3, #T_d4afa_row15_col4, #T_d4afa_row15_col6, #T_d4afa_row15_col7, #T_d4afa_row15_col8, #T_d4afa_row15_col9, #T_d4afa_row15_col16 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d4afa_row0_col2, #T_d4afa_row14_col9, #T_d4afa_row14_col16 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_d4afa_row0_col3 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_d4afa_row0_col4 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_d4afa_row0_col6, #T_d4afa_row9_col0, #T_d4afa_row12_col1, #T_d4afa_row14_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_d4afa_row0_col7, #T_d4afa_row11_col10, #T_d4afa_row16_col13 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_d4afa_row0_col8 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_
{
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_d4afa_row5_col10, #T_d4afa_row9_col10 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_d4afa_row5_col11, #T_d4afa_row10_col3 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_d4afa_row5_col12, #T_d4afa_row5_col15, #T_d4afa_row7_col1, #T_d4afa_row13_col14 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_d4afa_row5_col13, #T_d4afa_row8_col14 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_d4afa_row6_col1, #T_d4afa_row7_col9, #T_d4afa_row11_col5, #T_d4afa_row13_col12 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_d4afa_row6_col5 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_d4afa_row6_col7, #T_d4afa_row8_col9, #T_d4afa_row9_col4, #T_d4afa_row9_col16, #T_d4afa_row12_col3 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_d4afa_row6_col8, #T_d4afa_row7_col8, #T_d4afa_row16_col6 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_d4afa_row6_col9 {
#   background-color:

# %%
variable_redundante = df_num[['carlength', 'carwidth', 'curbweight', 'cylindernumber', 'enginesize']]

# %%
variable_redundante.head()
# Out:
#    carlength  carwidth  curbweight  cylindernumber  enginesize
# 0      168.8      64.1        2548               4         130
# 1      168.8      64.1        2548               4         130
# 2      171.2      65.5        2823               6         152
# 3      176.6      66.2        2337               4         109
# 4      176.6      66.4        2824               5         136

# %%
df_num.columns
# Out:
# Index(['symboling', 'doornumber', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'cylindernumber', 'enginesize', 'boreratio',
#        'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'citympg',
#        'highwaympg', 'price'],
#       dtype='object')

# %%
df_num = df_num.drop([variable_redundante],axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df_num = df_num.drop([variable_redundante],axis=1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:6692, in Index.drop(self, labels, errors)
#    6689     arr_dtype = "object" if self.dtype == "object" else None
#    6690     labels = com.index_labels_to_array(labels, dtype=arr_dtype)
# -> 6692 indexer = self.get_indexer_for(labels)
#    6693 mask = indexer == -1
#    6694 if mask.any():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:5858, in Index.get_indexer_for(self, target)
#    5840 """
#    5841 Guaranteed return of an indexer even when non-unique.
#    5842
#    (...)
#    5855 array([0, 2])
#    5856 """
#    5857 if self._index_as_unique:
# -> 5858     return self.get_indexer(target)
#    5859 indexer, _ = self.get_indexer_non_unique(target)
#    5860 return indexer
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3726, in Index.get_indexer(self, target, method, limit, tolerance)
#    3724 method = clean_reindex_fill_method(method)
#    3725 orig_target = target
# -> 3726 target = self._maybe_cast_listlike_indexer(target)
#    3728 self._check_indexing_method(method, limit, tolerance)
#    3730 if not self._index_as_unique:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:6362, in Index._maybe_cast_listlike_indexer(self, target)
#    6358 def _maybe_cast_listlike_indexer(self, target) -> Index:
#    6359     """
#    6360     Analogue to maybe_cast_indexer for get_indexer instead of get_loc.
#    6361     """
# -> 6362     return ensure_index(target)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:7125, in ensure_index(index_like, copy)
#    7123         return Index(index_like, copy=copy, tupleize_cols=False)
#    7124 else:
# -> 7125     return Index(index_like, copy=copy)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:551, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     548         data = com.asarray_tuplesafe(data, dtype=_dtype_obj)
#     550 try:
# --> 551     arr = sanitize_array(data, None, dtype=dtype, copy=copy)
#     552 except ValueError as err:
#     553     if "index must be specified when data is not list-like" in str(err):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\construction.py:569, in sanitize_array(data, index, dtype, copy, allow_2d)
#     567 subarr = data
#     568 if data.dtype == object:
# --> 569     subarr = maybe_infer_to_datetimelike(data)
#     571 if subarr is data and copy:
#     572     subarr = subarr.copy()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\cast.py:1181, in maybe_infer_to_datetimelike(value)
#    1178     raise TypeError(type(value))  # pragma: no cover
#    1179 if value.ndim != 1:
#    1180     # Caller is responsible
# -> 1181     raise ValueError(value.ndim)  # pragma: no cover
#    1183 if not len(value):
#    1184     return value
#
# ValueError: 3
